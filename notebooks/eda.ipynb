# %%
import pandas as pd

# %%
train = pd.read_csv('../data/train.csv')

# %%
train['qid'].value_counts().max()
# Out:
# 1

# %%
display(train.target.value_counts())
train.target.value_counts() / train.shape[0]
# Out:
# target
# 0    1225312
# 1      80810
# Name: count, dtype: int64
# target
# 0    0.93813
# 1    0.06187
# Name: count, dtype: float64

# %%
pd.set_option('display.max_colwidth', None)
train[train.target == 0].sample(10).question_text.to_frame()
# Out:
#                                                                 question_text
# 229441                    How have Mauri shoes become popular over the years?
# 292829           What is the real science research on creative visualization?
# 782151         How do ensure that the downtime data that we have is accurate?
# 293083                       How does music affect the individual as a whole?
# 1188296                              Why so many Indians on Quora hate China?
# 358582       Should one confess to someone even knowing they'll get rejected?
# 1110938                             What are reasons to keep nuclear weapons?
# 180032                                    Why doesn’t India recognize Kosovo?
# 142512   How does A college write a internship letter to a company or a bank?
# 33956                                        What is method for MCQ question?

# %%
train[train.target == 1].sample(10).question_text.to_frame()
# Out:
#                                                                                                                            question_text
# 233522                                                                                       Why are answers from Christians so useless?
# 1140152                                  Why do Indians boast about their great culture when they themselves have forgotten its essence?
# 1046362                                                                       Why don't the Greeks ally with the Kurds to attack Turkey?
# 1059668                                                                                                Do Indian girls like doggy-style?
# 430118                                                                                                  Why do people hate white people?
# 950225                                                                                               Is eating ice cream considered gay?
# ...

# %%
test = pd.read_csv('../data/test.csv')
test
# Out:
#                          qid  \
# 0       0000163e3ea7c7a74cd7
# 1       00002bd4fb5d505b9161
# 2       00007756b4a147d2b0b3
# 3       000086e4b7e1c7146103
# 4       0000c4c3fbe8785a3090
# ...                      ...
# 375801  ffff7fa746bd6d6197a9
# 375802  ffffa1be31c43046ab6b
# 375803  ffffae173b6ca6bfa563
# 375804  ffffb1f7f1a008620287
# 375805  fffff85473f4699474b0
#
#                                             question_text
# 0       Why do so many women become so rude and arroga...
# 1       When should I apply for RV college of engineer...
# 2       What is it really like to be a nurse practitio...
# 3                                  Who are entrepreneurs?
# 4        Is education really making good people nowadays?
# ...                                                   ...
# 375801  How many countries listed in gold import in in...
# 375802  Is there an alternative to dresses on formal p...
# 375803  Where I can find best friendship quotes in Tel...
# ...

# %%
pd.read_csv('../data/sample_submission.csv')
# Out:
#                          qid  prediction
# 0       0000163e3ea7c7a74cd7           0
# 1       00002bd4fb5d505b9161           0
# 2       00007756b4a147d2b0b3           0
# 3       000086e4b7e1c7146103           0
# 4       0000c4c3fbe8785a3090           0
# ...                      ...         ...
# 375801  ffff7fa746bd6d6197a9           0
# 375802  ffffa1be31c43046ab6b           0
# 375803  ffffae173b6ca6bfa563           0
# 375804  ffffb1f7f1a008620287           0
# 375805  fffff85473f4699474b0           0
#
# [375806 rows x 2 columns]
